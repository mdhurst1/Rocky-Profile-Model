# %%
# import modules
import numpy as np
from scipy import stats 
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import rc
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition, mark_inset)
import pandas as pd
import math
# %matplotlib inline

# %%
# Read Text File in Python
# load posterior data file from dakota with accepted samples 
Filename = "posterior_SM_test1.dat"  #"RPM_dakota_w.dat"
DF = pd.read_csv(Filename,sep = "\s+|\t+|\s+\t+|\t+\s+",engine='python')
DF.head()
# Out:
#    mcmc_id interface        FR         K         Y      rmse  CRNrmse
# 0        1     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62
# 1        2     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62
# 2        3     NO_ID  1.641706 -3.478398 -1.588790  1.831960  1549.09
# 3        4     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01
# 4        5     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01

# %%
#loop through rows of dataframe
#if current rmse matches previous rmse: sample has been rejected 
#we want to remove repeated samples for posterior distributions 
DF['Reject'] = DF.rmse.eq(DF.rmse.shift())   
    
DF.head()
# Out:
#    mcmc_id interface        FR         K         Y      rmse  CRNrmse  Reject
# 0        1     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62   False
# 1        2     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62    True
# 2        3     NO_ID  1.641706 -3.478398 -1.588790  1.831960  1549.09   False
# 3        4     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01   False
# 4        5     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01    True

# %%
#load dakota file with calculated log likelihoods 
Like_file = "raw_chain_loglikelihood_SM_test1.m"
DF_Like = pd.read_csv(Like_file,sep = "\s+|\t+|\s+\t+|\t+\s+",engine='python')
DF_Like.head()
#DF.to_csv("Likelihood.csv")
# Out:
#       Like
# 0 -6.57974
# 1 -6.57974
# 2 -6.41606
# 3 -4.35371
# 4 -4.35371

# %%
#add likelihood column to posterior dataframe 
DF['Like'] = DF_Like.Like
DF.head(10)
# Out:
#    mcmc_id interface        FR         K         Y      rmse  CRNrmse  Reject  \
# 0        1     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62   False
# 1        2     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62    True
# 2        3     NO_ID  1.641706 -3.478398 -1.588790  1.831960  1549.09   False
# 3        4     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01   False
# 4        5     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01    True
# 5        6     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28   False
# 6        7     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28    True
# 7        8     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28    True
# 8        9     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28    True
# 9       10     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28    True
#
#       Like
# 0 -6.57974
# 1 -6.57974
# 2 -6.41606
# 3 -4.35371
# 4 -4.35371
# 5 -6.37413
# 6 -6.37413
# 7 -6.37413
# 8 -6.37413
# 9 -6.37413

# %%
#remove repeated samples from dataframe 
#new_DF = DF.query("Reject = False")
new_DF = DF[DF.Reject==False]
new_DF = new_DF.reset_index(drop=True)
new_DF.head(10)
# Out:
#    mcmc_id interface        FR         K         Y      rmse  CRNrmse  Reject  \
# 0        1     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62   False
# 1        3     NO_ID  1.641706 -3.478398 -1.588790  1.831960  1549.09   False
# 2        4     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01   False
# 3        6     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28   False
# 4       11     NO_ID  2.867350 -2.658376 -1.472506  1.359620  1714.91   False
# 5       13     NO_ID  2.297888 -2.456457 -1.418616  1.150050  1786.63   False
# 6       24     NO_ID  1.827100 -2.967671 -1.361243  0.975747  1713.89   False
# 7       27     NO_ID  2.632690 -3.091843 -1.547736  0.945069  1926.82   False
# 8       30     NO_ID  2.690065 -3.749509 -1.657428  0.915836  2375.45   False
# 9       34     NO_ID  2.876500 -2.656612 -1.652666  1.165760  1625.02   False
#
#       Like
# 0 -6.57974
# 1 -6.41606
# 2 -4.35371
# 3 -6.37413
# 4 -4.88589
# 5 -4.37228
# 6 -3.87017
# 7 -4.05546
# 8 -4.62127
# 9 -4.23424

# %%
#save edited file to csv
new_DF.to_csv("Accepted_Final_SM_test1.csv")
new_DF.head()
# Out:
#    mcmc_id interface        FR         K         Y      rmse  CRNrmse  Reject  \
# 0        1     NO_ID  2.000000 -4.000000 -1.400000  0.780884  3530.62   False
# 1        3     NO_ID  1.641706 -3.478398 -1.588790  1.831960  1549.09   False
# 2        4     NO_ID  1.855062 -3.408226 -1.382437  0.839622  2299.01   False
# 3        6     NO_ID  1.198227 -4.001504 -1.469654  1.612860  2213.28   False
# 4       11     NO_ID  2.867350 -2.658376 -1.472506  1.359620  1714.91   False
#
#       Like
# 0 -6.57974
# 1 -6.41606
# 2 -4.35371
# 3 -6.37413
# 4 -4.88589
